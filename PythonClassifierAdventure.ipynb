# %%
# Load Spark

# %%
import os
from pyspark import *

# %%
# Connect to the default SparkCluster, change the master to have control over this

# %%
sc = SparkContext()

# %%
from pyspark.sql import *
from pyspark.sql.types import *

# %%
session = SparkSession.builder.getOrCreate()

# %% [markdown]
# Create a Python2Vec model using PySpark source code as the input, we do this using the sc + wholeTextFiles so we can get access on a per-file basis

# %%
from pyspark.find_spark_home import _find_spark_home
spark_home = _find_spark_home()

# %%
spark_files_rdd = sc.wholeTextFiles(spark_home)
pyspark_files_rdd = spark_files_rdd.filter(lambda x: x[0].endswith(".py"))

# %% [markdown]
# Now we want to tokenize the pyspark_files_rdd - we could do spaces but Python is our friend!

# %%
def tokenize_pyspark_file(file_contents):
    """Tokenize the PySpark files, for now this is targetted towards word2vec but we could build some interesting stuff on top of it - like looking at the comments etc."""
    import tokenize
    import StringIO
    raw_tokens = tokenize.generate_tokens(StringIO.StringIO(file_contents).readline)
    # Strip positional information from the tokens
    stripped_tokens = map(lambda x: (x[0], x[1]), raw_tokens)
    # Turn the result into a list since it gets pickled
    return list(stripped_tokens)

# %%
tokenized_files = (pyspark_files_rdd
        .map(lambda file_name_and_contents: tokenize_pyspark_file(file_name_and_contents[1]))
        .filter(lambda tokens: tokens)
                  )

# %%
tokenized_files.take(1)
# Out:
# [[(53, u'#'),
#   (54, u'\n'),
#   (53,
#    u'# Licensed to the Apache Software Foundation (ASF) under one or more'),
#   (54, u'\n'),
#   (53,
#    u'# contributor license agreements.  See the NOTICE file distributed with'),
#   (54, u'\n'),
#   (53,
#    u'# this work for additional information regarding copyright ownership.'),
#   (54, u'\n'),
#   (53,
#    u'# The ASF licenses this file to You under the Apache License, Version 2.0'),
#   (54, u'\n'),
#   (53,
#    u'# (the "License"); you may not use this file except in compliance with'),
#   (54, u'\n'),
#   (53, u'# the License.  You may obtain a copy of the License at'),
#   (54, u'\n'),
#   (53, u'#'),
#   (54, u'\n'),
#   (53, u'#    http://www.apache.org/licenses/LICENSE-2.0'),
#   (54, u'\n'),
#   (53, u'#'),
#   (54, u'\n'),
#   (53,
#    u'# Unless required by applicable law or agreed to in writing, software'),
#   (54, u'\n'),
#   (53, u'# distributed under the License is distributed on an "AS IS" BASIS,'),
#   (54, u'\n'),
#   (53,
#    u'# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.'),
#   (54, u'\n'),
#   (53,
#    u'# See the License for the specific language governing permissions and'),
#   (54, u'\n'),
#   (53, u'# limitations under the License.'),
#   (54, u'\n'),
#   (53, u'#'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (3, u'"""\nWorker that receives input from Piped RDD.\n"""'),
#   (4, u'\n'),
#   (1, u'from'),
#   (1, u'__future__'),
#   (1, u'import'),
#   (1, u'print_function'),
#   (4, u'\n'),
#   (1, u'import'),
#   (1, u'os'),
#   (4, u'\n'),
#   (1, u'import'),
#   (1, u'sys'),
#   (4, u'\n'),
#   (1, u'import'),
#   (1, u'time'),
#   (4, u'\n'),
#   (1, u'import'),
#   (1, u'socket'),
#   (4, u'\n'),
#   (1, u'import'),
#   (1, u'traceback'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (1, u'from'),
#   (1, u'pyspark'),
#   (51, u'.'),
#   (1, u'accumulators'),
#   (1, u'import'),
#   (1, u'_accumulatorRegistry'),
#   (4, u'\n'),
#   (1, u'from'),
#   (1, u'pyspark'),
#   (51, u'.'),
#   (1, u'broadcast'),
#   (1, u'import'),
#   (1, u'Broadcast'),
#   (51, u','),
#   (1, u'_broadcastRegistry'),
#   (4, u'\n'),
#   (1, u'from'),
#   (1, u'pyspark'),
#   (51, u'.'),
#   (1, u'files'),
#   (1, u'import'),
#   (1, u'SparkFiles'),
#   (4, u'\n'),
#   (1, u'from'),
#   (1, u'pyspark'),
#   (51, u'.'),
#   (1, u'serializers'),
#   (1, u'import'),
#   (1, u'write_with_length'),
#   (51, u','),
#   (1, u'write_int'),
#   (51, u','),
#   (1, u'read_long'),
#   (51, u','),
#   (1, u'write_long'),
#   (51, u','),
#   (1, u'read_int'),
#   (51, u','),
#   (1, u'SpecialLengths'),
#   (51, u','),
#   (1, u'UTF8Deserializer'),
#   (51, u','),
#   (1, u'PickleSerializer'),
#   (51, u','),
#   (1, u'BatchedSerializer'),
#   (4, u'\n'),
#   (1, u'from'),
#   (1, u'pyspark'),
#   (1, u'import'),
#   (1, u'shuffle'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (1, u'pickleSer'),
#   (51, u'='),
#   (1, u'PickleSerializer'),
#   (51, u'('),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'utf8_deserializer'),
#   (51, u'='),
#   (1, u'UTF8Deserializer'),
#   (51, u'('),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (1, u'def'),
#   (1, u'report_times'),
#   (51, u'('),
#   (1, u'outfile'),
#   (51, u','),
#   (1, u'boot'),
#   (51, u','),
#   (1, u'init'),
#   (51, u','),
#   (1, u'finish'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (1, u'write_int'),
#   (51, u'('),
#   (1, u'SpecialLengths'),
#   (51, u'.'),
#   (1, u'TIMING_DATA'),
#   (51, u','),
#   (1, u'outfile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'write_long'),
#   (51, u'('),
#   (1, u'int'),
#   (51, u'('),
#   (2, u'1000'),
#   (51, u'*'),
#   (1, u'boot'),
#   (51, u')'),
#   (51, u','),
#   (1, u'outfile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'write_long'),
#   (51, u'('),
#   (1, u'int'),
#   (51, u'('),
#   (2, u'1000'),
#   (51, u'*'),
#   (1, u'init'),
#   (51, u')'),
#   (51, u','),
#   (1, u'outfile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'write_long'),
#   (51, u'('),
#   (1, u'int'),
#   (51, u'('),
#   (2, u'1000'),
#   (51, u'*'),
#   (1, u'finish'),
#   (51, u')'),
#   (51, u','),
#   (1, u'outfile'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'def'),
#   (1, u'add_path'),
#   (51, u'('),
#   (1, u'path'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (53, u'# worker can be used, so donot add path multiple times'),
#   (54, u'\n'),
#   (5, u'    '),
#   (1, u'if'),
#   (1, u'path'),
#   (1, u'not'),
#   (1, u'in'),
#   (1, u'sys'),
#   (51, u'.'),
#   (1, u'path'),
#   (51, u':'),
#   (4, u'\n'),
#   (53, u'# overwrite system packages'),
#   (54, u'\n'),
#   (5, u'        '),
#   (1, u'sys'),
#   (51, u'.'),
#   (1, u'path'),
#   (51, u'.'),
#   (1, u'insert'),
#   (51, u'('),
#   (2, u'1'),
#   (51, u','),
#   (1, u'path'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (6, ''),
#   (1, u'def'),
#   (1, u'read_command'),
#   (51, u'('),
#   (1, u'serializer'),
#   (51, u','),
#   (1, u'file'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (1, u'command'),
#   (51, u'='),
#   (1, u'serializer'),
#   (51, u'.'),
#   (1, u'_read_with_length'),
#   (51, u'('),
#   (1, u'file'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'isinstance'),
#   (51, u'('),
#   (1, u'command'),
#   (51, u','),
#   (1, u'Broadcast'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'        '),
#   (1, u'command'),
#   (51, u'='),
#   (1, u'serializer'),
#   (51, u'.'),
#   (1, u'loads'),
#   (51, u'('),
#   (1, u'command'),
#   (51, u'.'),
#   (1, u'value'),
#   (51, u')'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'return'),
#   (1, u'command'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'def'),
#   (1, u'chain'),
#   (51, u'('),
#   (1, u'f'),
#   (51, u','),
#   (1, u'g'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (3, u'"""chain two function together """'),
#   (4, u'\n'),
#   (1, u'return'),
#   (1, u'lambda'),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u':'),
#   (1, u'g'),
#   (51, u'('),
#   (1, u'f'),
#   (51, u'('),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u')'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'def'),
#   (1, u'wrap_udf'),
#   (51, u'('),
#   (1, u'f'),
#   (51, u','),
#   (1, u'return_type'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (1, u'if'),
#   (1, u'return_type'),
#   (51, u'.'),
#   (1, u'needConversion'),
#   (51, u'('),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'        '),
#   (1, u'toInternal'),
#   (51, u'='),
#   (1, u'return_type'),
#   (51, u'.'),
#   (1, u'toInternal'),
#   (4, u'\n'),
#   (1, u'return'),
#   (1, u'lambda'),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u':'),
#   (1, u'toInternal'),
#   (51, u'('),
#   (1, u'f'),
#   (51, u'('),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u')'),
#   (51, u')'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'else'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'        '),
#   (1, u'return'),
#   (1, u'lambda'),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u':'),
#   (1, u'f'),
#   (51, u'('),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (6, ''),
#   (1, u'def'),
#   (1, u'read_single_udf'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (1, u'num_arg'),
#   (51, u'='),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'arg_offsets'),
#   (51, u'='),
#   (51, u'['),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (1, u'for'),
#   (1, u'i'),
#   (1, u'in'),
#   (1, u'range'),
#   (51, u'('),
#   (1, u'num_arg'),
#   (51, u')'),
#   (51, u']'),
#   (4, u'\n'),
#   (1, u'row_func'),
#   (51, u'='),
#   (1, u'None'),
#   (4, u'\n'),
#   (1, u'for'),
#   (1, u'i'),
#   (1, u'in'),
#   (1, u'range'),
#   (51, u'('),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'        '),
#   (1, u'f'),
#   (51, u','),
#   (1, u'return_type'),
#   (51, u'='),
#   (1, u'read_command'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'row_func'),
#   (1, u'is'),
#   (1, u'None'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'row_func'),
#   (51, u'='),
#   (1, u'f'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'else'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'row_func'),
#   (51, u'='),
#   (1, u'chain'),
#   (51, u'('),
#   (1, u'row_func'),
#   (51, u','),
#   (1, u'f'),
#   (51, u')'),
#   (4, u'\n'),
#   (53, u'# the last returnType will be the return type of UDF'),
#   (54, u'\n'),
#   (6, ''),
#   (6, ''),
#   (1, u'return'),
#   (1, u'arg_offsets'),
#   (51, u','),
#   (1, u'wrap_udf'),
#   (51, u'('),
#   (1, u'row_func'),
#   (51, u','),
#   (1, u'return_type'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'def'),
#   (1, u'read_udfs'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (1, u'num_udfs'),
#   (51, u'='),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'num_udfs'),
#   (51, u'=='),
#   (2, u'1'),
#   (51, u':'),
#   (4, u'\n'),
#   (53, u'# fast path for single UDF'),
#   (54, u'\n'),
#   (5, u'        '),
#   (1, u'_'),
#   (51, u','),
#   (1, u'udf'),
#   (51, u'='),
#   (1, u'read_single_udf'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'mapper'),
#   (51, u'='),
#   (1, u'lambda'),
#   (1, u'a'),
#   (51, u':'),
#   (1, u'udf'),
#   (51, u'('),
#   (51, u'*'),
#   (1, u'a'),
#   (51, u')'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'else'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'        '),
#   (1, u'udfs'),
#   (51, u'='),
#   (51, u'{'),
#   (51, u'}'),
#   (4, u'\n'),
#   (1, u'call_udf'),
#   (51, u'='),
#   (51, u'['),
#   (51, u']'),
#   (4, u'\n'),
#   (1, u'for'),
#   (1, u'i'),
#   (1, u'in'),
#   (1, u'range'),
#   (51, u'('),
#   (1, u'num_udfs'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'arg_offsets'),
#   (51, u','),
#   (1, u'udf'),
#   (51, u'='),
#   (1, u'read_single_udf'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'udfs'),
#   (51, u'['),
#   (3, u"'f%d'"),
#   (51, u'%'),
#   (1, u'i'),
#   (51, u']'),
#   (51, u'='),
#   (1, u'udf'),
#   (4, u'\n'),
#   (1, u'args'),
#   (51, u'='),
#   (51, u'['),
#   (3, u'"a[%d]"'),
#   (51, u'%'),
#   (1, u'o'),
#   (1, u'for'),
#   (1, u'o'),
#   (1, u'in'),
#   (1, u'arg_offsets'),
#   (51, u']'),
#   (4, u'\n'),
#   (1, u'call_udf'),
#   (51, u'.'),
#   (1, u'append'),
#   (51, u'('),
#   (3, u'"f%d(%s)"'),
#   (51, u'%'),
#   (51, u'('),
#   (1, u'i'),
#   (51, u','),
#   (3, u'", "'),
#   (51, u'.'),
#   (1, u'join'),
#   (51, u'('),
#   (1, u'args'),
#   (51, u')'),
#   (51, u')'),
#   (51, u')'),
#   (4, u'\n'),
#   (53, u'# Create function like this:'),
#   (54, u'\n'),
#   (53, u'#   lambda a: (f0(a0), f1(a1, a2), f2(a3))'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'mapper_str'),
#   (51, u'='),
#   (3, u'"lambda a: (%s)"'),
#   (51, u'%'),
#   (51, u'('),
#   (3, u'", "'),
#   (51, u'.'),
#   (1, u'join'),
#   (51, u'('),
#   (1, u'call_udf'),
#   (51, u')'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'mapper'),
#   (51, u'='),
#   (1, u'eval'),
#   (51, u'('),
#   (1, u'mapper_str'),
#   (51, u','),
#   (1, u'udfs'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'func'),
#   (51, u'='),
#   (1, u'lambda'),
#   (1, u'_'),
#   (51, u','),
#   (1, u'it'),
#   (51, u':'),
#   (1, u'map'),
#   (51, u'('),
#   (1, u'mapper'),
#   (51, u','),
#   (1, u'it'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'ser'),
#   (51, u'='),
#   (1, u'BatchedSerializer'),
#   (51, u'('),
#   (1, u'PickleSerializer'),
#   (51, u'('),
#   (51, u')'),
#   (51, u','),
#   (2, u'100'),
#   (51, u')'),
#   (4, u'\n'),
#   (53, u'# profiling is not supported for UDF'),
#   (54, u'\n'),
#   (1, u'return'),
#   (1, u'func'),
#   (51, u','),
#   (1, u'None'),
#   (51, u','),
#   (1, u'ser'),
#   (51, u','),
#   (1, u'ser'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'def'),
#   (1, u'main'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u','),
#   (1, u'outfile'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'    '),
#   (1, u'try'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'        '),
#   (1, u'boot_time'),
#   (51, u'='),
#   (1, u'time'),
#   (51, u'.'),
#   (1, u'time'),
#   (51, u'('),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'split_index'),
#   (51, u'='),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'split_index'),
#   (51, u'=='),
#   (51, u'-'),
#   (2, u'1'),
#   (51, u':'),
#   (53, u'# for unit tests'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'exit'),
#   (51, u'('),
#   (51, u'-'),
#   (2, u'1'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'version'),
#   (51, u'='),
#   (1, u'utf8_deserializer'),
#   (51, u'.'),
#   (1, u'loads'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'version'),
#   (51, u'!='),
#   (3, u'"%d.%d"'),
#   (51, u'%'),
#   (1, u'sys'),
#   (51, u'.'),
#   (1, u'version_info'),
#   (51, u'['),
#   (51, u':'),
#   (2, u'2'),
#   (51, u']'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'raise'),
#   (1, u'Exception'),
#   (51, u'('),
#   (51, u'('),
#   (3, u'"Python in worker has different version %s than that in "'),
#   (51, u'+'),
#   (54, u'\n'),
#   (3, u'"driver %s, PySpark cannot run with different minor versions."'),
#   (51, u'+'),
#   (54, u'\n'),
#   (3, u'"Please check environment variables PYSPARK_PYTHON and "'),
#   (51, u'+'),
#   (54, u'\n'),
#   (3, u'"PYSPARK_DRIVER_PYTHON are correctly set."'),
#   (51, u')'),
#   (51, u'%'),
#   (54, u'\n'),
#   (51, u'('),
#   (3, u'"%d.%d"'),
#   (51, u'%'),
#   (1, u'sys'),
#   (51, u'.'),
#   (1, u'version_info'),
#   (51, u'['),
#   (51, u':'),
#   (2, u'2'),
#   (51, u']'),
#   (51, u','),
#   (1, u'version'),
#   (51, u')'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (53, u'# initialize global state'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'shuffle'),
#   (51, u'.'),
#   (1, u'MemoryBytesSpilled'),
#   (51, u'='),
#   (2, u'0'),
#   (4, u'\n'),
#   (1, u'shuffle'),
#   (51, u'.'),
#   (1, u'DiskBytesSpilled'),
#   (51, u'='),
#   (2, u'0'),
#   (4, u'\n'),
#   (1, u'_accumulatorRegistry'),
#   (51, u'.'),
#   (1, u'clear'),
#   (51, u'('),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (53, u'# fetch name of workdir'),
#   (54, u'\n'),
#   (1, u'spark_files_dir'),
#   (51, u'='),
#   (1, u'utf8_deserializer'),
#   (51, u'.'),
#   (1, u'loads'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'SparkFiles'),
#   (51, u'.'),
#   (1, u'_root_directory'),
#   (51, u'='),
#   (1, u'spark_files_dir'),
#   (4, u'\n'),
#   (1, u'SparkFiles'),
#   (51, u'.'),
#   (1, u'_is_running_on_worker'),
#   (51, u'='),
#   (1, u'True'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (53,
#    u'# fetch names of includes (*.zip and *.egg files) and construct PYTHONPATH'),
#   (54, u'\n'),
#   (1, u'add_path'),
#   (51, u'('),
#   (1, u'spark_files_dir'),
#   (51, u')'),
#   (53, u'# *.py files that were added will be copied here'),
#   (4, u'\n'),
#   (1, u'num_python_includes'),
#   (51, u'='),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'for'),
#   (1, u'_'),
#   (1, u'in'),
#   (1, u'range'),
#   (51, u'('),
#   (1, u'num_python_includes'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'filename'),
#   (51, u'='),
#   (1, u'utf8_deserializer'),
#   (51, u'.'),
#   (1, u'loads'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'add_path'),
#   (51, u'('),
#   (1, u'os'),
#   (51, u'.'),
#   (1, u'path'),
#   (51, u'.'),
#   (1, u'join'),
#   (51, u'('),
#   (1, u'spark_files_dir'),
#   (51, u','),
#   (1, u'filename'),
#   (51, u')'),
#   (51, u')'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'if'),
#   (1, u'sys'),
#   (51, u'.'),
#   (1, u'version'),
#   (51, u'>'),
#   (3, u"'3'"),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'import'),
#   (1, u'importlib'),
#   (4, u'\n'),
#   (1, u'importlib'),
#   (51, u'.'),
#   (1, u'invalidate_caches'),
#   (51, u'('),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (53, u'# fetch names and values of broadcast variables'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'num_broadcast_variables'),
#   (51, u'='),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'for'),
#   (1, u'_'),
#   (1, u'in'),
#   (1, u'range'),
#   (51, u'('),
#   (1, u'num_broadcast_variables'),
#   (51, u')'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'bid'),
#   (51, u'='),
#   (1, u'read_long'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'bid'),
#   (51, u'>='),
#   (2, u'0'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'                '),
#   (1, u'path'),
#   (51, u'='),
#   (1, u'utf8_deserializer'),
#   (51, u'.'),
#   (1, u'loads'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'_broadcastRegistry'),
#   (51, u'['),
#   (1, u'bid'),
#   (51, u']'),
#   (51, u'='),
#   (1, u'Broadcast'),
#   (51, u'('),
#   (1, u'path'),
#   (51, u'='),
#   (1, u'path'),
#   (51, u')'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'else'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'                '),
#   (1, u'bid'),
#   (51, u'='),
#   (51, u'-'),
#   (1, u'bid'),
#   (51, u'-'),
#   (2, u'1'),
#   (4, u'\n'),
#   (1, u'_broadcastRegistry'),
#   (51, u'.'),
#   (1, u'pop'),
#   (51, u'('),
#   (1, u'bid'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (6, ''),
#   (1, u'_accumulatorRegistry'),
#   (51, u'.'),
#   (1, u'clear'),
#   (51, u'('),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'is_sql_udf'),
#   (51, u'='),
#   (1, u'read_int'),
#   (51, u'('),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (1, u'if'),
#   (1, u'is_sql_udf'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'func'),
#   (51, u','),
#   (1, u'profiler'),
#   (51, u','),
#   (1, u'deserializer'),
#   (51, u','),
#   (1, u'serializer'),
#   (51, u'='),
#   (1, u'read_udfs'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (6, ''),
#   (1, u'else'),
#   (51, u':'),
#   (4, u'\n'),
#   (5, u'            '),
#   (1, u'func'),
#   (51, u','),
#   (1, u'profiler'),
#   (51, u','),
#   (1, u'deserializer'),
#   (51, u','),
#   (1, u'serializer'),
#   (51, u'='),
#   (1, u'read_command'),
#   (51, u'('),
#   (1, u'pickleSer'),
#   (51, u','),
#   (1, u'infile'),
#   (51, u')'),
#   (4, u'\n'),
#   (54, u'\n'),
#   (6, ''),
#   (1, u'init_time'),
#   ...]]

# %%
# Shove it back into strings and convert it to a DataFrame

# %%
tokenized_df = tokenized_files.map(lambda x: Row(tokens=str(x))).toDF(schema=StructType([StructField("tokens", StringType(), False)]))

# %%
tokenized_df.take(1)
# Out:
# [Row(tokens=u'[(53, u\'#\'), (54, u\'\\n\'), (53, u\'# Licensed to the Apache Software Foundation (ASF) under one or more\'), (54, u\'\\n\'), (53, u\'# contributor license agreements.  See the NOTICE file distributed with\'), (54, u\'\\n\'), (53, u\'# this work for additional information regarding copyright ownership.\'), (54, u\'\\n\'), (53, u\'# The ASF licenses this file to You under the Apache License, Version 2.0\'), (54, u\'\\n\'), (53, u\'# (the "License"); you may not use this file except in compliance with\'), (54, u\'\\n\'), (53, u\'# the License.  You may obtain a copy of the License at\'), (54, u\'\\n\'), (53, u\'#\'), (54, u\'\\n\'), (53, u\'#    http://www.apache.org/licenses/LICENSE-2.0\'), (54, u\'\\n\'), (53, u\'#\'), (54, u\'\\n\'), (53, u\'# Unless required by applicable law or agreed to in writing, software\'), (54, u\'\\n\'), (53, u\'# distributed under the License is distributed on an "AS IS" BASIS,\'), (54, u\'\\n\'), (53, u\'# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.\'), (54, u\'\\n\'), (53, u\'# See the License for the specific language governing permissions and\'), (54, u\'\\n\'), (53, u\'# limitations under the License.\'), (54, u\'\\n\'), (53, u\'#\'), (54, u\'\\n\'), (54, u\'\\n\'), (3, u\'"""\\nWorker that receives input from Piped RDD.\\n"""\'), (4, u\'\\n\'), (1, u\'from\'), (1, u\'__future__\'), (1, u\'import\'), (1, u\'print_function\'), (4, u\'\\n\'), (1, u\'import\'), (1, u\'os\'), (4, u\'\\n\'), (1, u\'import\'), (1, u\'sys\'), (4, u\'\\n\'), (1, u\'import\'), (1, u\'time\'), (4, u\'\\n\'), (1, u\'import\'), (1, u\'socket\'), (4, u\'\\n\'), (1, u\'import\'), (1, u\'traceback\'), (4, u\'\\n\'), (54, u\'\\n\'), (1, u\'from\'), (1, u\'pyspark\'), (51, u\'.\'), (1, u\'accumulators\'), (1, u\'import\'), (1, u\'_accumulatorRegistry\'), (4, u\'\\n\'), (1, u\'from\'), (1, u\'pyspark\'), (51, u\'.\'), (1, u\'broadcast\'), (1, u\'import\'), (1, u\'Broadcast\'), (51, u\',\'), (1, u\'_broadcastRegistry\'), (4, u\'\\n\'), (1, u\'from\'), (1, u\'pyspark\'), (51, u\'.\'), (1, u\'files\'), (1, u\'import\'), (1, u\'SparkFiles\'), (4, u\'\\n\'), (1, u\'from\'), (1, u\'pyspark\'), (51, u\'.\'), (1, u\'serializers\'), (1, u\'import\'), (1, u\'write_with_length\'), (51, u\',\'), (1, u\'write_int\'), (51, u\',\'), (1, u\'read_long\'), (51, u\',\'), (1, u\'write_long\'), (51, u\',\'), (1, u\'read_int\'), (51, u\',\'), (1, u\'SpecialLengths\'), (51, u\',\'), (1, u\'UTF8Deserializer\'), (51, u\',\'), (1, u\'PickleSerializer\'), (51, u\',\'), (1, u\'BatchedSerializer\'), (4, u\'\\n\'), (1, u\'from\'), (1, u\'pyspark\'), (1, u\'import\'), (1, u\'shuffle\'), (4, u\'\\n\'), (54, u\'\\n\'), (1, u\'pickleSer\'), (51, u\'=\'), (1, u\'PickleSerializer\'), (51, u\'(\'), (51, u\')\'), (4, u\'\\n\'), (1, u\'utf8_deserializer\'), (51, u\'=\'), (1, u\'UTF8Deserializer\'), (51, u\'(\'), (51, u\')\'), (4, u\'\\n\'), (54, u\'\\n\'), (54, u\'\\n\'), (1, u\'def\'), (1, u\'report_times\'), (51, u\'(\'), (1, u\'outfile\'), (51, u\',\'), (1, u\'boot\'), (51, u\',\'), (1, u\'init\'), (51, u\',\'), (1, u\'finish\'), (51, u\')\'), (51, u\':\'), (4, u\'\\n\'), (5, u\'    \'), (1, u\'write_int\'), (51, u\'(\'), (1, u\'SpecialLengths\'), (51, u\'.\'), (1, u\'TIMING_DATA\'), (51, u\',\'), (1, u\'outfile\'), (51, u\')\'), (4, u\'\\n\'), (1, u\'write_long\'), (51, u\'(\'), (1, u\'int\'), (51, u\'(\'), (2, u\'1000\'), (51, u\'*\'), (1, u\'boot\'), (51, u\')\'), (51, u\',\'), (1, u\'outfile\'), (51, u\')\'), (4, u\'\\n\'), (1, u\'write_long\'), (51, u\'(\'), (1, u\'int\'), (51, u\'(\'), (2, u\'1000\'), (51, u\'*\'), (1, u\'init\'), (51, u\')\'), (51, u\',\'), (1, u\'outfile\'), (51, u\')\'), (4, u\'\\n\'), (1, u\'write_long\'), (51, u\'(\'), (1, u\'int\'), (51, u\'(\'), (2, u\'1000\'), (51, u\'*\'), (1, u\'finish\'), (51, u\')\'), (51, u\',\'), (1, u\'outfile\'), (51, u\')\'), (4, u\'\\n\'), (54, u\'\\n\'), (54, u\'\\n\'), (6, \'\'), (1, u\'def\'), (1, u\'add_path\'), (51, u\'(\'), (1, u\'path\'), (51, u\')\'), (51 ...

# %% [markdown]
# Now we start creating a word2vec (or py2vec :p) model :) - shout out to lab41 who did something similar while trying to recommend source code

# %%
from pyspark.ml import Word2Vec
word2vec_estimator = Word2Vec().setInputCol("tokens")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-88-7b5afa565c82> in <module>()
# ----> 1 from pyspark.ml import Word2Vec
#       2 word2vec_estimator = Word2Vec().setInputCol("tokens")
#
# /home/holden/spark-venv/local/lib/python2.7/site-packages/pyspark/ml/__init__.py in <module>()
#      20 machine learning pipelines.
#      21 """
# ---> 22 from pyspark.ml.base import Estimator, Model, Transformer
#      23 from pyspark.ml.pipeline import Pipeline, PipelineModel
#      24
#
# /home/holden/spark-venv/local/lib/python2.7/site-packages/pyspark/ml/base.py in <module>()
#      19
#      20 from pyspark import since
# ---> 21 from pyspark.ml.param import Params
#      22 from pyspark.ml.common import inherit_doc
#      23
#
# ImportError: No module named param
